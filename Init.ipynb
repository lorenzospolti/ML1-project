# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# !pip install -r requirements.txt
# Out:
# Collecting mlxtend==0.23.3
#   Downloading mlxtend-0.23.3-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 80.7 MB/s eta 0:00:00
# Collecting imblearn==0.0
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Requirement already satisfied: missingno==0.5.2 in /root/venv/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (0.5.2)
# Collecting xgboost==2.1.4
#   Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl (223.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: lightgbm==4.6.0 in /root/venv/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (4.6.0)
# Requirement already satisfied: catboost==1.2.8 in /root/venv/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (1.2.8)
# Requirement already satisfied: matplotlib>=3.0.0 in /root/venv/lib/python3.10/site-packages (from mlxtend==0.23.3->-r requirements.txt (line 1)) (3.6.3)
# Requirement already satisfied: pandas>=0.24.2 in /root/venv/lib/python3.10/site-packages (from mlxtend==0.23.3->-r requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: scipy>=1.2.1 in /root/venv/lib/python3.10/site-packages (from mlxtend==0.23.3->-r requirements.txt (line 1)) (1.9.3)
# Requirement already satisfied: joblib>=0.13.2 in /root/venv/lib/python3.10/site-packages (from mlxtend==0.23.3->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: numpy>=1.16.2 in /root/venv/lib/python3.10/site-packages (from mlxtend==0.23.3->-r requirements.txt (line 1)) (1.25.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /root/venv/lib/python3.10/site-packages (from mlxtend==0.23.3->-r requirements.txt (line 1)) (1.7.0)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: seaborn in /root/venv/lib/python3.10/site-packages (from missingno==0.5.2->-r requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /root/venv/lib/python3.10/site-packages (from xgboost==2.1.4->-r requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: plotly in /root/venv/lib/python3.10/site-packages (from catboost==1.2.8->-r requirements.txt (line 8)) (6.0.1)
# Requirement already satisfied: graphviz in /root/venv/lib/python3.10/site-packages (from catboost==1.2.8->-r requirements.txt (line 8)) (0.21)
# Requirement already satisfied: six in /root/venv/lib/python3.10/site-packages (from catboost==1.2.8->-r requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: pillow>=6.2.0 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (4.57.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (3.2.3)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend==0.23.3->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend==0.23.3->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn>=1.3.1->mlxtend==0.23.3->-r requirements.txt (line 1)) (3.6.0)
# Collecting scipy>=1.2.1
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 82.0 MB/s eta 0:00:00
# Collecting sklearn-compat<1,>=0.1
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /root/venv/lib/python3.10/site-packages (from plotly->catboost==1.2.8->-r requirements.txt (line 8)) (1.38.0)
# Collecting scikit-learn>=1.3.1
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 129.7 MB/s eta 0:00:00
# Installing collected packages: scipy, xgboost, scikit-learn, sklearn-compat, mlxtend, imbalanced-learn, imblearn
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.3
#     Uninstalling scipy-1.9.3:
#       Successfully uninstalled scipy-1.9.3
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 3.0.2
#     Uninstalling xgboost-3.0.2:
#       Successfully uninstalled xgboost-3.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.0
#     Uninstalling scikit-learn-1.7.0:
#       Successfully uninstalled scikit-learn-1.7.0
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.23.4
#     Uninstalling mlxtend-0.23.4:
#       Successfully uninstalled mlxtend-0.23.4
# Successfully installed imbalanced-learn-0.13.0 imblearn-0.0 mlxtend-0.23.3 scikit-learn-1.6.1 scipy-1.15.3 sklearn-compat-0.1.3 xgboost-2.1.4
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=0ed69efa-1cff-4e1b-967d-f67d3cac50cf' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
